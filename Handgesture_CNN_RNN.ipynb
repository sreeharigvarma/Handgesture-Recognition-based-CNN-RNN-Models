# %%
import numpy as np
import os
from skimage.transform import resize
from imageio import imread
import datetime
import os
import warnings
warnings.filterwarnings("ignore")
import abc
from sys import getsizeof

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# importing some other libraries which will be needed for model building.

# from keras.models import Sequential, Model
# from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
# from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
# from keras.layers.recurrent import LSTM
# from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# from keras import optimizers
# from keras.layers import Dropout
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dropout

# %%
project_folder='/home/datasets/Project_data/'

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        # filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
        # filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}'
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5.keras'


        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')#, save_top_k=1
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, initial_epoch=0)
        
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=10,num_epochs=5)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# 2024-06-05 15:59:03.548555: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-05 15:59:03.548620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1b:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 160, 160, 16)  1312
#
#  activation (Activation)     (None, 30, 160, 160, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 160, 160, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 80, 80, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 80, 80, 32)    4128
#
#  activation_1 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 40, 40, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 40, 40, 64)     16448
#
#  activation_2 (Activation)   (None, 7, 40, 40, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 20, 20, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 20, 20, 128)    65664
#
#  activation_3 (Activation)   (None, 3, 20, 20, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________

# %% [markdown]
# ### 1.1. Model_0 sample cropping

# %%
test_generator=ModelConv3D1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=15)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])

# %% [markdown]
# ## Selecting  Image resolution, number of frames and batch_size

# %%
# Training
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# Epoch 1/5
# 67/67 [==============================] - ETA: 0s - loss: 1.6672 - categorical_accuracy: 0.3786
# Epoch 00001: val_loss improved from inf to 6.10691, saving model to model_init_2024-06-0514_06_04.746523/model-00001-1.66724-0.37858-6.10691-0.21000.h5.keras
# 67/67 [==============================] - 293s 4s/step - loss: 1.6672 - categorical_accuracy: 0.3786 - val_loss: 6.1069 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/5
# 67/67 [==============================] - ETA: 0s - loss: 1.1365 - categorical_accuracy: 0.5475
# Epoch 00002: val_loss did not improve from 6.10691
# 67/67 [==============================] - 238s 4s/step - loss: 1.1365 - categorical_accuracy: 0.5475 - val_loss: 7.7939 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/5
# 67/67 [==============================] - ETA: 0s - loss: 1.0202 - categorical_accuracy: 0.6003
# Epoch 00003: val_loss did not improve from 6.10691
# 67/67 [==============================] - 191s 3s/step - loss: 1.0202 - categorical_accuracy: 0.6003 - val_loss: 7.4079 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 4/5
# 67/67 [==============================] - ETA: 0s - loss: 0.9974 - categorical_accuracy: 0.6305
# Epoch 00004: val_loss improved from 6.10691 to 5.21953, saving model to model_init_2024-06-0514_06_04.746523/model-00004-0.99738-0.63047-5.21953-0.21000.h5.keras
# 67/67 [==============================] - 179s 3s/step - loss: 0.9974 - categorical_accuracy: 0.6305 - val_loss: 5.2195 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/5
# 67/67 [==============================] - ETA: 0s - loss: 0.8219 - categorical_accuracy: 0.6848
# Epoch 00005: val_loss improved from 5.21953 to 4.77640, saving model to model_init_2024-06-0514_06_04.746523/model-00005-0.82190-0.68477-4.77640-0.20000.h5.keras
# 67/67 [==============================] - 178s 3s/step - loss: 0.8219 - categorical_accuracy: 0.6848 - val_loss: 4.7764 - val_categorical_accuracy: 0.2000 - lr: 0.0010

# %%
plot(history_model1)

# %%
print (history_model1.history['loss'])
# Out:
# 1

# %% [markdown]
# ## 1.2 Summary:
# - We can say **"image resolution"** and **number of frames** in sequence have more impact on training time than **batch_size**
# - Currently batch size we tried 5,10,15,20 and get the same result. We can consider the Batch Size around 15-40
# - We will change the resoulution 160*160, 120*120 according the model performance

# %% [markdown]
# # Model 1 ( Batch Size = 40 and No. of Epochs = 15)

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 160, 160, 16)  1312
#
#  activation_8 (Activation)   (None, 20, 160, 160, 16)  0
#
#  batch_normalization_12 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 80, 80, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_9 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_13 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_10 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_14 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_11 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_15 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 12800)             0
#
#  dense_6 (Dense)             (None, 64)                819264
#
#  batch_normalization_16 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  batch_normalization_17 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# Epoch 1/15
# 17/17 [==============================] - ETA: 0s - loss: 1.4945 - categorical_accuracy: 0.4314
# Epoch 00001: val_loss improved from inf to 1.56638, saving model to model_init_2024-06-0514_37_04.067741/model-00001-1.49454-0.43137-1.56638-0.22000.h5.keras
# 17/17 [==============================] - 126s 8s/step - loss: 1.4945 - categorical_accuracy: 0.4314 - val_loss: 1.5664 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/15
# 17/17 [==============================] - ETA: 0s - loss: 1.0378 - categorical_accuracy: 0.5822
# Epoch 00002: val_loss did not improve from 1.56638
# 17/17 [==============================] - 125s 8s/step - loss: 1.0378 - categorical_accuracy: 0.5822 - val_loss: 1.8116 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/15
# 17/17 [==============================] - ETA: 0s - loss: 0.7098 - categorical_accuracy: 0.7360
# Epoch 00003: val_loss did not improve from 1.56638
# 17/17 [==============================] - 117s 7s/step - loss: 0.7098 - categorical_accuracy: 0.7360 - val_loss: 2.8637 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/15
# 17/17 [==============================] - ETA: 0s - loss: 0.5750 - categorical_accuracy: 0.7919
# Epoch 00004: val_loss did not improve from 1.56638
# 17/17 [==============================] - 120s 7s/step - loss: 0.5750 - categorical_accuracy: 0.7919 - val_loss: 3.9294 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 5/15
# 17/17 [==============================] - ETA: 0s - loss: 0.4156 - categorical_accuracy: 0.8537
# Epoch 00005: val_loss did not improve from 1.56638
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 17/17 [==============================] - 118s 7s/step - loss: 0.4156 - categorical_accuracy: 0.8537 - val_loss: 4.4723 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 6/15
# 17/17 [==============================] - ETA: 0s - loss: 0.3237 - categorical_accuracy: 0.8869
# Epoch 00006: val_loss did not improve from 1.56638
# 17/17 [==============================] - 116s 7s/step - loss: 0.3237 - categorical_accuracy: 0.8869 - val_loss: 4.9445 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 7/15
# 17/17 [==============================] - ETA: 0s - loss: 0.2585 - categorical_accuracy: 0.9186
# Epoch 00007: val_loss did not improve from 1.56638
# 17/17 [==============================] - 118s 7s/step - loss: 0.2585 - categorical_accuracy: 0.9186 - val_loss: 5.3044 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 8/15
# 17/17 [==============================] - ETA: 0s - loss: 0.2153 - categorical_accuracy: 0.9412
# Epoch 00008: val_loss did not improve from 1.56638
# 17/17 [==============================] - 117s 7s/step - loss: 0.2153 - categorical_accuracy: 0.9412 - val_loss: 6.0321 - val_categorical_accuracy: 0.1300 - lr: 2.0000e-04
# Epoch 9/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1752 - categorical_accuracy: 0.9608
# Epoch 00009: val_loss did not improve from 1.56638
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 17/17 [==============================] - 116s 7s/step - loss: 0.1752 - categorical_accuracy: 0.9608 - val_loss: 5.7361 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 10/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1596 - categorical_accuracy: 0.9653
# Epoch 00010: val_loss did not improve from 1.56638
# 17/17 [==============================] - 118s 7s/step - loss: 0.1596 - categorical_accuracy: 0.9653 - val_loss: 5.8419 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 11/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1574 - categorical_accuracy: 0.9653
# Epoch 00011: val_loss did not improve from 1.56638
# 17/17 [==============================] - 119s 7s/step - loss: 0.1574 - categorical_accuracy: 0.9653 - val_loss: 6.1258 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %%
plot(history_model1)

# %% [markdown]
# ## Model1 Summary:
# * Seems like our model is not learning much and there is very high overfitting
# * Good observation is that the early stopping is working. As you can see that we have set epochs for 15 but stoped at 11
# * Lets try adding some dropout layers

# %% [markdown]
# # Model 2 (Adding dropout layers - Batch Size = 20 and No. of Epochs = 15)

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=15)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 20, 160, 160, 16)  1312
#
#  activation_4 (Activation)   (None, 20, 160, 160, 16)  0
#
#  batch_normalization_6 (Batc  (None, 20, 160, 160, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 10, 80, 80, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 10, 80, 80, 32)    13856
#
#  activation_5 (Activation)   (None, 10, 80, 80, 32)    0
#
#  batch_normalization_7 (Batc  (None, 10, 80, 80, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 5, 40, 40, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 5, 40, 40, 64)     55360
#
#  activation_6 (Activation)   (None, 5, 40, 40, 64)     0
#
#  batch_normalization_8 (Batc  (None, 5, 40, 40, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 2, 20, 20, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 2, 20, 20, 128)    221312
#
#  activation_7 (Activation)   (None, 2, 20, 20, 128)    0
#
#  batch_normalization_9 (Batc  (None, 2, 20, 20, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 10, 10, 128)   0
#  3D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_3 (Dense)             (None, 256)               3277056
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/15
# 34/34 [==============================] - ETA: 0s - loss: 1.9351 - categorical_accuracy: 0.3846
# Epoch 00001: val_loss improved from inf to 3.33307, saving model to model_init_2024-06-0515_09_59.486222/model-00001-1.93507-0.38462-3.33307-0.22000.h5.keras
# 34/34 [==============================] - 243s 7s/step - loss: 1.9351 - categorical_accuracy: 0.3846 - val_loss: 3.3331 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/15
# 34/34 [==============================] - ETA: 0s - loss: 1.4811 - categorical_accuracy: 0.5045
# Epoch 00002: val_loss did not improve from 3.33307
# 34/34 [==============================] - 235s 7s/step - loss: 1.4811 - categorical_accuracy: 0.5045 - val_loss: 3.7508 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 3/15
# 34/34 [==============================] - ETA: 0s - loss: 1.2511 - categorical_accuracy: 0.5747
# Epoch 00003: val_loss did not improve from 3.33307
# 34/34 [==============================] - 242s 7s/step - loss: 1.2511 - categorical_accuracy: 0.5747 - val_loss: 4.2807 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 4/15
# 34/34 [==============================] - ETA: 0s - loss: 1.0027 - categorical_accuracy: 0.6478
# Epoch 00004: val_loss did not improve from 3.33307
# 34/34 [==============================] - 286s 9s/step - loss: 1.0027 - categorical_accuracy: 0.6478 - val_loss: 6.2086 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 5/15
# 34/34 [==============================] - ETA: 0s - loss: 0.8067 - categorical_accuracy: 0.7134
# Epoch 00005: val_loss did not improve from 3.33307
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 289s 9s/step - loss: 0.8067 - categorical_accuracy: 0.7134 - val_loss: 6.2421 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 6/15
# 34/34 [==============================] - ETA: 0s - loss: 0.7593 - categorical_accuracy: 0.7255
# Epoch 00006: val_loss did not improve from 3.33307
# 34/34 [==============================] - 241s 7s/step - loss: 0.7593 - categorical_accuracy: 0.7255 - val_loss: 5.9610 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 7/15
# 34/34 [==============================] - ETA: 0s - loss: 0.6723 - categorical_accuracy: 0.7496
# Epoch 00007: val_loss did not improve from 3.33307
# 34/34 [==============================] - 233s 7s/step - loss: 0.6723 - categorical_accuracy: 0.7496 - val_loss: 6.8241 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 8/15
# 34/34 [==============================] - ETA: 0s - loss: 0.5941 - categorical_accuracy: 0.7821
# Epoch 00008: val_loss did not improve from 3.33307
# 34/34 [==============================] - 239s 7s/step - loss: 0.5941 - categorical_accuracy: 0.7821 - val_loss: 6.0851 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 9/15
# 34/34 [==============================] - ETA: 0s - loss: 0.5541 - categorical_accuracy: 0.8009
# Epoch 00009: val_loss did not improve from 3.33307
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 229s 7s/step - loss: 0.5541 - categorical_accuracy: 0.8009 - val_loss: 5.5387 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 10/15
# 34/34 [==============================] - ETA: 0s - loss: 0.5026 - categorical_accuracy: 0.8250
# Epoch 00010: val_loss did not improve from 3.33307
# 34/34 [==============================] - 227s 7s/step - loss: 0.5026 - categorical_accuracy: 0.8250 - val_loss: 5.0999 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 11/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4796 - categorical_accuracy: 0.8318
# Epoch 00011: val_loss did not improve from 3.33307
# 34/34 [==============================] - 227s 7s/step - loss: 0.4796 - categorical_accuracy: 0.8318 - val_loss: 4.2885 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %%
# plot(history_model2)
plot(loaded_model.history)

# %% [markdown]
# # Model 3 (Reduce filter size to (2,2,2) and image res to 120 x 120, - Batch Size = 60  and No. of Epochs = 12)

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=60,num_epochs=15)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 16, 120, 120, 16)  400
#
#  activation_8 (Activation)   (None, 16, 120, 120, 16)  0
#
#  batch_normalization_12 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 8, 60, 60, 16)    0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 8, 60, 60, 32)     4128
#
#  activation_9 (Activation)   (None, 8, 60, 60, 32)     0
#
#  batch_normalization_13 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 4, 30, 30, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_10 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_14 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_11 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 256)               1605888
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/15
# 2024-06-05 16:18:39.934608: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 12/12 [==============================] - ETA: 0s - loss: 2.1648 - categorical_accuracy: 0.3288
# Epoch 00001: val_loss improved from inf to 1.65589, saving model to model_init_2024-06-0516_18_19.532578/model-00001-2.16483-0.32881-1.65589-0.16000.h5.keras
# 12/12 [==============================] - 199s 18s/step - loss: 2.1648 - categorical_accuracy: 0.3288 - val_loss: 1.6559 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/15
# 12/12 [==============================] - ETA: 0s - loss: 1.5342 - categorical_accuracy: 0.4646
# Epoch 00002: val_loss did not improve from 1.65589
# 12/12 [==============================] - 157s 14s/step - loss: 1.5342 - categorical_accuracy: 0.4646 - val_loss: 1.9903 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 3/15
# 12/12 [==============================] - ETA: 0s - loss: 1.3007 - categorical_accuracy: 0.5339
# Epoch 00003: val_loss did not improve from 1.65589
# 12/12 [==============================] - 155s 14s/step - loss: 1.3007 - categorical_accuracy: 0.5339 - val_loss: 2.3462 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 4/15
# 12/12 [==============================] - ETA: 0s - loss: 1.2207 - categorical_accuracy: 0.5679
# Epoch 00004: val_loss did not improve from 1.65589
# 12/12 [==============================] - 152s 14s/step - loss: 1.2207 - categorical_accuracy: 0.5679 - val_loss: 2.9190 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 5/15
# 12/12 [==============================] - ETA: 0s - loss: 1.1592 - categorical_accuracy: 0.5799
# Epoch 00005: val_loss did not improve from 1.65589
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 12/12 [==============================] - 155s 14s/step - loss: 1.1592 - categorical_accuracy: 0.5799 - val_loss: 3.5945 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/15
# 12/12 [==============================] - ETA: 0s - loss: 1.0858 - categorical_accuracy: 0.6026
# Epoch 00006: val_loss did not improve from 1.65589
# 12/12 [==============================] - 153s 14s/step - loss: 1.0858 - categorical_accuracy: 0.6026 - val_loss: 4.0221 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/15
# 12/12 [==============================] - ETA: 0s - loss: 1.1001 - categorical_accuracy: 0.5973
# Epoch 00007: val_loss did not improve from 1.65589
# 12/12 [==============================] - 186s 17s/step - loss: 1.1001 - categorical_accuracy: 0.5973 - val_loss: 4.5129 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 8/15
# 12/12 [==============================] - ETA: 0s - loss: 1.1312 - categorical_accuracy: 0.5965
# Epoch 00008: val_loss did not improve from 1.65589
# 12/12 [==============================] - 153s 14s/step - loss: 1.1312 - categorical_accuracy: 0.5965 - val_loss: 4.8915 - val_categorical_accuracy: 0.1500 - lr: 4.0000e-05
# Epoch 9/15
# 12/12 [==============================] - ETA: 0s - loss: 1.0624 - categorical_accuracy: 0.6252
# Epoch 00009: val_loss did not improve from 1.65589
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 12/12 [==============================] - 173s 16s/step - loss: 1.0624 - categorical_accuracy: 0.6252 - val_loss: 5.2945 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 10/15
# 12/12 [==============================] - ETA: 0s - loss: 1.0639 - categorical_accuracy: 0.6176
# Epoch 00010: val_loss did not improve from 1.65589
# 12/12 [==============================] - 156s 14s/step - loss: 1.0639 - categorical_accuracy: 0.6176 - val_loss: 5.2932 - val_categorical_accuracy: 0.1600 - lr: 8.0000e-06
# Epoch 11/15
# 11/12 [==========================>...] - ETA: 13s - loss: 1.0482 - categorical_accuracy: 0.6045
# Epoch 00011: val_loss did not improve from 1.65589
# 12/12 [==============================] - 154s 14s/step - loss: 1.0505 - categorical_accuracy: 0.6033 - val_loss: 5.9237 - val_categorical_accuracy: 0.1600 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model3)

# %% [markdown]
# # Model 4 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 18, 120, 120, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 18, 120, 120, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 18, 60, 60, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 18, 60, 60, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 18, 60, 60, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 18, 30, 30, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 18, 30, 30, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 18, 30, 30, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 18, 15, 15, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 18, 15, 15, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 18, 7, 7, 256)    295168
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 18, 7, 7, 256)    1024
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 18, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 18, 2304)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               1245696
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model4=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3425 - categorical_accuracy: 0.4268
# Epoch 00001: val_loss improved from inf to 1.73137, saving model to model_init_2024-06-0517_02_49.806798/model-00001-1.34245-0.42685-1.73137-0.21000.h5.keras
# 34/34 [==============================] - 230s 7s/step - loss: 1.3425 - categorical_accuracy: 0.4268 - val_loss: 1.7314 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0903 - categorical_accuracy: 0.5543
# Epoch 00002: val_loss did not improve from 1.73137
# 34/34 [==============================] - 183s 6s/step - loss: 1.0903 - categorical_accuracy: 0.5543 - val_loss: 1.9032 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9246 - categorical_accuracy: 0.6312
# Epoch 00003: val_loss did not improve from 1.73137
# 34/34 [==============================] - 182s 6s/step - loss: 0.9246 - categorical_accuracy: 0.6312 - val_loss: 2.2312 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9071 - categorical_accuracy: 0.6403
# Epoch 00004: val_loss did not improve from 1.73137
# 34/34 [==============================] - 180s 5s/step - loss: 0.9071 - categorical_accuracy: 0.6403 - val_loss: 1.9144 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8028 - categorical_accuracy: 0.6991
# Epoch 00005: val_loss did not improve from 1.73137
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 183s 6s/step - loss: 0.8028 - categorical_accuracy: 0.6991 - val_loss: 1.9274 - val_categorical_accuracy: 0.3100 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6303 - categorical_accuracy: 0.7640
# Epoch 00006: val_loss did not improve from 1.73137
# 34/34 [==============================] - 222s 7s/step - loss: 0.6303 - categorical_accuracy: 0.7640 - val_loss: 2.1077 - val_categorical_accuracy: 0.3100 - lr: 2.0000e-04
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5346 - categorical_accuracy: 0.8054
# Epoch 00007: val_loss did not improve from 1.73137
# 34/34 [==============================] - 193s 6s/step - loss: 0.5346 - categorical_accuracy: 0.8054 - val_loss: 2.2668 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4853 - categorical_accuracy: 0.8175
# Epoch 00008: val_loss did not improve from 1.73137
# 34/34 [==============================] - 181s 5s/step - loss: 0.4853 - categorical_accuracy: 0.8175 - val_loss: 2.0293 - val_categorical_accuracy: 0.3600 - lr: 2.0000e-04
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4623 - categorical_accuracy: 0.8318
# Epoch 00009: val_loss did not improve from 1.73137
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 185s 6s/step - loss: 0.4623 - categorical_accuracy: 0.8318 - val_loss: 2.2525 - val_categorical_accuracy: 0.3600 - lr: 2.0000e-04
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4123 - categorical_accuracy: 0.8650
# Epoch 00010: val_loss did not improve from 1.73137
# 34/34 [==============================] - 215s 7s/step - loss: 0.4123 - categorical_accuracy: 0.8650 - val_loss: 2.0666 - val_categorical_accuracy: 0.3800 - lr: 4.0000e-05
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3811 - categorical_accuracy: 0.8695
# Epoch 00011: val_loss did not improve from 1.73137
# 34/34 [==============================] - 182s 6s/step - loss: 0.3811 - categorical_accuracy: 0.8695 - val_loss: 1.9320 - val_categorical_accuracy: 0.4000 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %%
plot(history_model4)

# %% [markdown]
# # Model 5 (CNN LSTM with GRU )

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class RNNCNN2(ModelBuilderMoreAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        

        model.add(TimeDistributed(Flatten()))


        model.add(GRU(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn2=RNNCNN2()
rnn_cnn2.initialize_path(project_folder)
rnn_cnn2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn2.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=4)
rnn_cnn2_model=rnn_cnn2.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn2_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_68 (TimeDi  (None, 18, 120, 120, 16)  448
#  stributed)
#
#  time_distributed_69 (TimeDi  (None, 18, 120, 120, 16)  64
#  stributed)
#
#  time_distributed_70 (TimeDi  (None, 18, 60, 60, 16)   0
#  stributed)
#
#  time_distributed_71 (TimeDi  (None, 18, 60, 60, 32)   4640
#  stributed)
#
#  time_distributed_72 (TimeDi  (None, 18, 60, 60, 32)   128
#  stributed)
#
#  time_distributed_73 (TimeDi  (None, 18, 30, 30, 32)   0
#  stributed)
#
#  time_distributed_74 (TimeDi  (None, 18, 30, 30, 64)   18496
#  stributed)
#
#  time_distributed_75 (TimeDi  (None, 18, 30, 30, 64)   256
#  stributed)
#
#  time_distributed_76 (TimeDi  (None, 18, 15, 15, 64)   0
#  stributed)
#
#  time_distributed_77 (TimeDi  (None, 18, 15, 15, 128)  73856
#  stributed)
#
#  time_distributed_78 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_79 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_80 (TimeDi  (None, 18, 6272)         0
#  stributed)
#
#  gru_4 (GRU)                 (None, 128)               2458368
#
#  dropout_16 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 128)               16512
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,573,925
# Trainable params: 2,573,445
# Non-trainable params: 480
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn2_model.count_params())
history_model5=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
# Out:
# Total Params: 2573925
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/4
# 34/34 [==============================] - ETA: 0s - loss: 1.5083 - categorical_accuracy: 0.3748
# Epoch 00001: saving model to model_init_2024-06-0517_46_00.953234/model-00001-1.50826-0.37481-1.78474-0.23000.h5
# 34/34 [==============================] - 198s 6s/step - loss: 1.5083 - categorical_accuracy: 0.3748 - val_loss: 1.7847 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 2/4
# 34/34 [==============================] - ETA: 0s - loss: 1.0750 - categorical_accuracy: 0.5641
# Epoch 00002: saving model to model_init_2024-06-0517_46_00.953234/model-00002-1.07498-0.56410-1.99418-0.15000.h5
# 34/34 [==============================] - 188s 6s/step - loss: 1.0750 - categorical_accuracy: 0.5641 - val_loss: 1.9942 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 3/4
# 34/34 [==============================] - ETA: 0s - loss: 0.8854 - categorical_accuracy: 0.6644
# Epoch 00003: saving model to model_init_2024-06-0517_46_00.953234/model-00003-0.88544-0.66440-2.05706-0.18000.h5
# 34/34 [==============================] - 183s 6s/step - loss: 0.8854 - categorical_accuracy: 0.6644 - val_loss: 2.0571 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 4/4
# 34/34 [==============================] - ETA: 0s - loss: 0.7369 - categorical_accuracy: 0.7360
# Epoch 00004: saving model to model_init_2024-06-0517_46_00.953234/model-00004-0.73687-0.73605-2.33285-0.12000.h5
# 34/34 [==============================] - 182s 5s/step - loss: 0.7369 - categorical_accuracy: 0.7360 - val_loss: 2.3328 - val_categorical_accuracy: 0.1200 - lr: 2.0000e-04

# %%
plot(history_model5)
